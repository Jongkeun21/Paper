# %% [markdown]
# # 12 layers, pre-trained weight

# %%
import tensorflow as tf
import numpy as np
import time
import os
import re

from PIL import Image as PI

# from tensorflow.examples.tutorials.mnist import input_data
# mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)

# %%
with tf.Session(config=tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)) as sess_ :
    saver = tf.train.import_meta_graph('D:/Backup_data/jongkeun/paper/dogs_cats_190618/dogs_cats_190618-156.meta')
    saver.restore(sess_, tf.train.latest_checkpoint('D:/Backup_data/jongkeun/paper/dogs_cats_190618/'))
    
    graph = tf.get_default_graph()
    
#     print(graph.get_tensor_by_name('layer0_conv2d_1/kernel:0'))
    weight0_1, weight0_2, weight0_3 = sess_.run([graph.get_tensor_by_name('layer0_conv2d_1/kernel:0'), 
                                                 graph.get_tensor_by_name('layer0_conv2d_2/kernel:0'),
                                                 graph.get_tensor_by_name('layer0_conv2d_3/kernel:0')])
    
    weight1, weight1_1, weight1_2, weight1_3 = sess_.run([graph.get_tensor_by_name('layer1_conv2d/kernel:0'), 
                                                          graph.get_tensor_by_name('layer1_conv2d_1/kernel:0'),
                                                          graph.get_tensor_by_name('layer1_conv2d_2/kernel:0'),
                                                          graph.get_tensor_by_name('layer1_conv2d_3/kernel:0')])
    
    weight2, weight2_1, weight2_2, weight2_3 = sess_.run([graph.get_tensor_by_name('layer2_conv2d/kernel:0'), 
                                                          graph.get_tensor_by_name('layer2_conv2d_1/kernel:0'),
                                                          graph.get_tensor_by_name('layer2_conv2d_2/kernel:0'),
                                                          graph.get_tensor_by_name('layer2_conv2d_3/kernel:0')])
    
    weight3, weight3_1, weight3_2, weight3_3 = sess_.run([graph.get_tensor_by_name('layer3_conv2d/kernel:0'), 
                                                          graph.get_tensor_by_name('layer3_conv2d_1/kernel:0'),
                                                          graph.get_tensor_by_name('layer3_conv2d_2/kernel:0'),
                                                          graph.get_tensor_by_name('layer3_conv2d_3/kernel:0')])
#     weight_ = weight[:,:,:,:]
#     print(weight_)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1107 13:32:46.544084 21324 deprecation.py:323] From C:\Users\whdrm\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.

# %%
training_epochs = 500
batch_size = 20
image_resize = 128
image_width = image_resize
image_height = image_resize
initial_rate = 1e-5
label_len = 3

home_dir = "D:/Backup_data/jongkeun"

image_file = "/dir_images/190819_newTraining/"
test_image_file = "/dir_images/190309_new_test/"

label_file = "/csv/190819_newTraining.csv"
test_label_file = "/csv/190309_new_test.csv"

# %%
label_dir = home_dir + label_file
test_label_dir = home_dir + test_label_file

# label_dir = os.getcwd() + "/csv/181126.csv"
# test_label_dir = os.getcwd() + "/csv/181126_test.csv"

f_label = open(label_dir, 'r')
f_test_label = open(test_label_dir, 'r')

label_data = f_label.readlines()
test_label_data = f_test_label.readlines()

f_label.close()
f_test_label.close()

label_array = np.array(np.reshape(label_data, [-1, label_len]), dtype=np.int32)
test_label_array = np.array(np.reshape(test_label_data, [-1, label_len]), dtype=np.int32)

print(len(label_array))
print(len(test_label_array))
# Out:
# 9182
# 1018

# %%
image_dir = home_dir + image_file
test_image_dir = home_dir + test_image_file

# image_dir = os.getcwd() + "/dir_images/181126/"
# test_image_dir = os.getcwd() + "/dir_images/181126_test/"

image_list = os.listdir(image_dir)
test_image_list = os.listdir(test_image_dir)

image_list = sorted(image_list, key=lambda x: (int(re.sub('\D','',x)),x))
test_image_list = sorted(test_image_list, key=lambda y: (int(re.sub('\D','',y)),y))

image_array = []
test_image_array = []

for i in range(len(image_list)) :
    image_list[i] = image_dir + image_list[i]
    image_array.append(np.array(PI.open(image_list[i]).resize((image_resize, image_resize)).convert('L')))

for j in range(len(test_image_list)) :
    test_image_list[j] = test_image_dir + test_image_list[j]
    test_image_array.append(np.array(PI.open(test_image_list[j]).resize((image_resize, image_resize)).convert('L')))

image_array = np.reshape(image_array, [-1, image_width*image_height])
test_image_array = np.reshape(test_image_array, [-1, image_width*image_height])

image_array = np.array(np.reshape(image_array, [-1, image_width, image_height, 1]), dtype=np.float32)
test_image_array = np.array(np.reshape(test_image_array, [-1, image_width, image_height, 1]), dtype=np.float32)

print(len(image_array))
print(len(test_image_array))
# Out:
# 9182
# 1018

# %%
x = tf.placeholder(dtype=tf.float32, shape=[None, image_width, image_height, 1], name='input_image')
y_ = tf.placeholder(dtype=tf.float32, shape=[None, label_len], name='input_label')
learning_rate = tf.placeholder(dtype=tf.float32, name='learning_rate')

# W_pre_trained = tf.placeholder(dtype=tf.float32, shape=[3,3,8,128], name='pre_trained_weight')

is_training = tf.placeholder(dtype=tf.bool)

# %%
W_h0_1 = tf.placeholder(dtype=tf.float32, shape=[3,3,1,8], name='W_h0_1')
W_h0_2 = tf.placeholder(dtype=tf.float32, shape=[3,3,8,128], name='W_h0_2')
W_h0_3 = tf.placeholder(dtype=tf.float32, shape=[3,3,128,256], name='W_h0_3')

W_h1 = tf.placeholder(dtype=tf.float32, shape=[3,3,256,256], name='W_h1')
W_h1_1 = tf.placeholder(dtype=tf.float32, shape=[3,3,256,128], name='W_h1_1')
W_h1_2 = tf.placeholder(dtype=tf.float32, shape=[3,3,128,256], name='W_h1_2')
W_h1_3 = tf.placeholder(dtype=tf.float32, shape=[3,3,256,512], name='W_h1_3')

W_h2 = tf.placeholder(dtype=tf.float32, shape=[3,3,512,512], name='W_h2')
W_h2_1 = tf.placeholder(dtype=tf.float32, shape=[3,3,512,256], name='W_h2_1')
W_h2_2 = tf.placeholder(dtype=tf.float32, shape=[3,3,256,512], name='W_h2_2')
W_h2_3 = tf.placeholder(dtype=tf.float32, shape=[3,3,512,1024], name='W_h2_3')

W_h3 = tf.placeholder(dtype=tf.float32, shape=[3,3,1024,512], name='W_h3')
W_h3_1 = tf.placeholder(dtype=tf.float32, shape=[3,3,512,1024], name='W_h3_1')
W_h3_2 = tf.placeholder(dtype=tf.float32, shape=[3,3,1024,512], name='W_h3_2')
W_h3_3 = tf.placeholder(dtype=tf.float32, shape=[3,3,512,256], name='W_h3_3')

# %%
def pooling(input_, dropout, is_training, name_maxpooling, name_dropout) :
#     layer = tf.layers.conv2d(input_data, size, [3, 3], padding='SAME', name=name_conv2d)
    pooling = tf.layers.average_pooling2d(input_, [2, 2], [2, 2], padding='SAME', name=name_maxpooling)
    pooling = tf.layers.dropout(pooling, dropout, is_training, name=name_dropout)
    
    return pooling

def learning_layer(input_data, size, dropout, is_training, name_conv2d, name_maxpooling, name_dropout) :
    layer = tf.layers.conv2d(input_data, size, [3, 3], padding='SAME', name=name_conv2d)
    layer = tf.layers.average_pooling2d(layer, [2, 2], [2, 2], padding='SAME', name=name_maxpooling)
    layer = tf.layers.dropout(layer, dropout, is_training, name=name_dropout)
    
    return layer

def convolutional(input_, weight_) :
    conv_ = tf.nn.conv2d(input_, weight_, strides=[1,1,1,1], padding='SAME')
    hidden_ = tf.nn.relu(conv_)
    
    return hidden_

with tf.device('/gpu:0') :
    layer0_1 = convolutional(x, W_h0_1)
    layer0_2 = convolutional(layer0_1, W_h0_2)
    layer1 = convolutional(layer0_2, W_h0_3)
    layer1_ = pooling(layer1, dropout=0.7, is_training=is_training, name_maxpooling="layer1_maxpooling", name_dropout="layer1_dropout")

    layer1_1 = convolutional(layer1_, W_h1)
    layer1_2 = convolutional(layer1_1, W_h1_1)
    layer2 = convolutional(layer1_2, W_h1_2)
    layer2_ = pooling(layer2, dropout=0.7, is_training=is_training, name_maxpooling="layer2_maxpooling", name_dropout="layer2_dropout")
    
    layer2_1 = convolutional(layer2_, W_h1_3)
    layer2_2 = convolutional(layer2_1, W_h2)
    layer3 = convolutional(layer2_2, W_h2_1)
    layer3_ = pooling(layer3, dropout=0.7, is_training=is_training, name_maxpooling="layer3_maxpooling", name_dropout="layer3_dropout")
    
    layer3_1 = convolutional(layer3_, W_h2_2)
    layer3_2 = convolutional(layer3_1, W_h2_3)
    layer4 = convolutional(layer3_2, W_h3)
    layer4_ = pooling(layer4, dropout=0.7, is_training=is_training, name_maxpooling="layer4_maxpooling", name_dropout="layer4_dropout")
# Out:
# W1107 13:35:12.147768 21324 deprecation.py:323] From <ipython-input-8-ee9d55466c9b>:3: average_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.AveragePooling2D instead.
# W1107 13:35:12.277395 21324 deprecation.py:323] From <ipython-input-8-ee9d55466c9b>:4: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.

# %%
with tf.device('/gpu:0') :
    fully_layer = tf.contrib.layers.flatten(layer4_)
    fully_layer = tf.layers.dense(fully_layer, 1024, activation=tf.nn.relu, name='fully_connected_layer')
    fully_layer = tf.layers.dropout(fully_layer, 0.5, is_training, name='fully_connected_dropout')

    fully_layer2 = tf.layers.dense(fully_layer, 512, activation=tf.nn.relu, name='fully_connected_layer2')
    fully_layer2 = tf.layers.dropout(fully_layer2, 0.5, is_training, name='fully_connected_dropout2')
    
#     fully_layer3 = tf.layers.dense(fully_layer2, 256, activation=tf.nn.relu, name='fully_connected_layer3')
#     fully_layer3 = tf.layers.dropout(fully_layer3, 0.5, is_training, name='fully_connected_dropout3')
# Out:
# W1107 13:35:15.378102 21324 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W1107 13:35:15.380105 21324 deprecation.py:323] From C:\Users\whdrm\Anaconda3\lib\site-packages\tensorflow\contrib\layers\python\layers\layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# W1107 13:35:15.621451 21324 deprecation.py:323] From <ipython-input-9-f6b2f4e2bc49>:3: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W1107 13:35:15.623446 21324 deprecation.py:506] From C:\Users\whdrm\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
with tf.device('/gpu:0') :
    logits = tf.layers.dense(fully_layer2, label_len, activation=None)
    
    with tf.name_scope('pred') : 
        pred = tf.nn.softmax(logits)
    with tf.name_scope('loss') :
        loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=y_))
#         loss = -tf.reduce_sum(y_ * tf.log(pred))
    with tf.name_scope('train') :
        train = tf.train.AdamOptimizer(learning_rate).minimize(loss)

with tf.device('/gpu:0') :
#     correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y_, 1))
    correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y_, 1))
    acc = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
    
    label_output = tf.argmax(pred, 1)
    label_input = tf.argmax(y_, 1)

# %%
config = tf.ConfigProto(log_device_placement = True, allow_soft_placement=True)
config.gpu_options.allow_growth = True

with tf.Session(config=config) as sess :
    coord = tf.train.Coordinator()
    thread = tf.train.start_queue_runners(sess=sess, coord=coord)
        
    sess.run(tf.global_variables_initializer())
    
    total_batch = int(len(image_list) / batch_size)
    correct_list = []
    incorrect_list = []
    cost_list = []
    cost_sum_list = []
    pred_list = []
    total_acc = 0
    cost_sum = 0
    cost_flag = 0
    rate_ = 1
    
    start_time = time.time()
    
    print("")
    
    for epoch in range(training_epochs) :
        total_cost = 0
        
        if epoch%50 == 49 :
                rate_ *= 0.8
                
        if epoch%10 == 9 :
#             rate_ *= 0.8
            midpoint = int(time.time() - start_time)
        
            print("")
            print("=======================================================================================")
            print('{:03d}:{:02d}:{:02d}'.format(midpoint//3600, (midpoint%3600//60), midpoint%60))
            print("=======================================================================================")
            print("")
        
        batch_index = np.random.choice(len(image_array), total_batch, replace=False)
                
        for i in range(total_batch) :                
            _, _loss = sess.run([train, loss], feed_dict={x: image_array[[batch_index[i]]], y_: label_array[[batch_index[i]]], 
                                                          is_training: True, learning_rate: initial_rate*rate_,
                                                          W_h0_1: weight0_1, W_h0_2: weight0_2, W_h0_3: weight0_3,
                                                          W_h1: weight1, W_h1_1: weight1_1, W_h1_2: weight1_2, W_h1_3: weight1_3,
                                                          W_h2: weight2, W_h2_1: weight2_1, W_h2_2: weight2_2, W_h2_3: weight2_3,
                                                          W_h3: weight3, W_h3_1: weight3_1, W_h3_2: weight3_2, W_h3_3: weight3_3})               
            total_cost += _loss

        avg_cost = total_cost/total_batch
        print('Epoch : ', '%4d' % (epoch + 1), '    Avg. cost = ', '{:.4f}'.format(avg_cost))            
        
#         train_writer.add_summary(_merge, epoch)
               
    print("")
    print("=======================================================================================")
    print("================================     Training done     ================================")
    print("=======================================================================================")
    print("")
    
    for test in range(len(test_image_array)) :
        _acc, _label_input, _label_output, _pred = sess.run([acc, label_input, label_output, pred], 
                             feed_dict={x: test_image_array[[test]], y_: test_label_array[[test]], is_training: False,
                                        W_h0_1: weight0_1, W_h0_2: weight0_2, W_h0_3: weight0_3,
                                        W_h1: weight1, W_h1_1: weight1_1, W_h1_2: weight1_2, W_h1_3: weight1_3,
                                        W_h2: weight2, W_h2_1: weight2_1, W_h2_2: weight2_2, W_h2_3: weight2_3,
                                        W_h3: weight3, W_h3_1: weight3_1, W_h3_2: weight3_2, W_h3_3: weight3_3})

        total_acc += _acc
        pred_list.append(list(_pred[0]))
        
        print("n: ", test, "    label_input: ", _label_input, "    label_output: ", _label_output)
        
        if _label_input == _label_output :
            correct_list.append(test)   
        else :
            incorrect_list.append(test)
        
    print("")
    print("          TOTAL ACC    : ", '{:.5f}'.format(total_acc / len(test_image_array)))
    print("")
    print(pred_list)
    
    end_time = int(time.time() - start_time)
    
    print("")
    print("=======================================================================================")
    print('{:03d}:{:02d}:{:02d}'.format(end_time//3600, (end_time%3600//60), end_time%60))
    print("=======================================================================================")
    print("")
    
    coord.request_stop()
    coord.join(thread)
# Out:
# W1107 13:35:16.179958 21324 deprecation.py:323] From <ipython-input-11-500c9753ef23>:6: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W1107 13:35:16.180955 21324 queue_runner_impl.py:471] `tf.train.start_queue_runners()` was called when no queue runners were defined. You can safely remove the call to this deprecated function.
# Epoch :     1     Avg. cost =  0.8587
# Epoch :     2     Avg. cost =  0.7189
# Epoch :     3     Avg. cost =  0.6166
# Epoch :     4     Avg. cost =  0.6183
# Epoch :     5     Avg. cost =  0.5877
# Epoch :     6     Avg. cost =  0.5999
# Epoch :     7     Avg. cost =  0.5933
# Epoch :     8     Avg. cost =  0.6101
# Epoch :     9     Avg. cost =  0.6523
#
# =======================================================================================
# 000:02:59
# =======================================================================================
#
# Epoch :    10     Avg. cost =  0.5767
# Epoch :    11     Avg. cost =  0.6246
# Epoch :    12     Avg. cost =  0.5819
# Epoch :    13     Avg. cost =  0.6090
# Epoch :    14     Avg. cost =  0.5918
# Epoch :    15     Avg. cost =  0.5616
# Epoch :    16     Avg. cost =  0.6111
# Epoch :    17     Avg. cost =  0.5879
# Epoch :    18     Avg. cost =  0.5674
# Epoch :    19     Avg. cost =  0.5413
#
# =======================================================================================
# 000:06:16
# =======================================================================================
#
# Epoch :    20     Avg. cost =  0.5670
# Epoch :    21     Avg. cost =  0.6401
# Epoch :    22     Avg. cost =  0.5777
# Epoch :    23     Avg. cost =  0.5494
# Epoch :    24     Avg. cost =  0.5244
# Epoch :    25     Avg. cost =  0.5763
# Epoch :    26     Avg. cost =  0.5682
# Epoch :    27     Avg. cost =  0.5839
# Epoch :    28     Avg. cost =  0.6016
# Epoch :    29     Avg. cost =  0.5295
#
# =======================================================================================
# 000:09:33
# =======================================================================================
#
# Epoch :    30     Avg. cost =  0.5573
# Epoch :    31     Avg. cost =  0.5696
# Epoch :    32     Avg. cost =  0.4844
# Epoch :    33     Avg. cost =  0.6026
# Epoch :    34     Avg. cost =  0.5174
# Epoch :    35     Avg. cost =  0.5941
# Epoch :    36     Avg. cost =  0.5140
# Epoch :    37     Avg. cost =  0.5281
# Epoch :    38     Avg. cost =  0.5714
# Epoch :    39     Avg. cost =  0.5251
#
# =======================================================================================
# 000:12:51
# =======================================================================================
#
# Epoch :    40     Avg. cost =  0.5016
# Epoch :    41     Avg. cost =  0.5414
# Epoch :    42     Avg. cost =  0.5240
# Epoch :    43     Avg. cost =  0.5544
# Epoch :    44     Avg. cost =  0.5190
# Epoch :    45     Avg. cost =  0.5369
# Epoch :    46     Avg. cost =  0.5271
# Epoch :    47     Avg. cost =  0.5261
# Epoch :    48     Avg. cost =  0.4855
# Epoch :    49     Avg. cost =  0.5344
#
# =======================================================================================
# 000:16:08
# =======================================================================================
#
# Epoch :    50     Avg. cost =  0.5452
# Epoch :    51     Avg. cost =  0.5358
# Epoch :    52     Avg. cost =  0.4818
# Epoch :    53     Avg. cost =  0.4940
# Epoch :    54     Avg. cost =  0.5668
# Epoch :    55     Avg. cost =  0.5334
# Epoch :    56     Avg. cost =  0.4792
# Epoch :    57     Avg. cost =  0.5594
# Epoch :    58     Avg. cost =  0.5278
# Epoch :    59     Avg. cost =  0.5168
#
# =======================================================================================
# 000:19:25
# =======================================================================================
#
# Epoch :    60     Avg. cost =  0.5492
# Epoch :    61     Avg. cost =  0.5580
# Epoch :    62     Avg. cost =  0.5058
# Epoch :    63     Avg. cost =  0.5359
# Epoch :    64     Avg. cost =  0.4952
# Epoch :    65     Avg. cost =  0.5587
# Epoch :    66     Avg. cost =  0.5312
# Epoch :    67     Avg. cost =  0.5274
# Epoch :    68     Avg. cost =  0.4584
# Epoch :    69     Avg. cost =  0.4978
#
# =======================================================================================
# 000:22:43
# =======================================================================================
#
# Epoch :    70     Avg. cost =  0.4604
# Epoch :    71     Avg. cost =  0.5122
# Epoch :    72     Avg. cost =  0.4713
# Epoch :    73     Avg. cost =  0.4641
# Epoch :    74     Avg. cost =  0.5290
# Epoch :    75     Avg. cost =  0.5047
# Epoch :    76     Avg. cost =  0.5373
# Epoch :    77     Avg. cost =  0.4809
# Epoch :    78     Avg. cost =  0.4705
# Epoch :    79     Avg. cost =  0.4336
#
# =======================================================================================
# 000:26:00
# =======================================================================================
#
# Epoch :    80     Avg. cost =  0.5558
# Epoch :    81     Avg. cost =  0.4528
# Epoch :    82     Avg. cost =  0.4152
# Epoch :    83     Avg. cost =  0.5301
# Epoch :    84     Avg. cost =  0.5254
# Epoch :    85     Avg. cost =  0.4459
# Epoch :    86     Avg. cost =  0.4999
# Epoch :    87     Avg. cost =  0.4551
# Epoch :    88     Avg. cost =  0.4883
# Epoch :    89     Avg. cost =  0.4879
#
# =======================================================================================
# 000:29:18
# =======================================================================================
#
# Epoch :    90     Avg. cost =  0.5215
# Epoch :    91     Avg. cost =  0.5027
# Epoch :    92     Avg. cost =  0.4933
# Epoch :    93     Avg. cost =  0.4296
# Epoch :    94     Avg. cost =  0.5003
# Epoch :    95     Avg. cost =  0.4582
# Epoch :    96     Avg. cost =  0.5020
# Epoch :    97     Avg. cost =  0.4881
# Epoch :    98     Avg. cost =  0.4387
# Epoch :    99     Avg. cost =  0.5111
#
# =======================================================================================
# 000:32:35
# =======================================================================================
#
# Epoch :   100     Avg. cost =  0.4798
# Epoch :   101     Avg. cost =  0.4719
# Epoch :   102     Avg. cost =  0.4897
# Epoch :   103     Avg. cost =  0.5079
# Epoch :   104     Avg. cost =  0.4584
# Epoch :   105     Avg. cost =  0.4061
# Epoch :   106     Avg. cost =  0.4992
# Epoch :   107     Avg. cost =  0.4858
# Epoch :   108     Avg. cost =  0.4209
# Epoch :   109     Avg. cost =  0.5248
#
# =======================================================================================
# 000:35:53
# =======================================================================================
#
# Epoch :   110     Avg. cost =  0.4809
# Epoch :   111     Avg. cost =  0.4907
# Epoch :   112     Avg. cost =  0.4525
# Epoch :   113     Avg. cost =  0.4490
# Epoch :   114     Avg. cost =  0.4706
# Epoch :   115     Avg. cost =  0.5296
# Epoch :   116     Avg. cost =  0.4971
# Epoch :   117     Avg. cost =  0.4542
# Epoch :   118     Avg. cost =  0.4528
# Epoch :   119     Avg. cost =  0.4582
#
# =======================================================================================
# 000:39:11
# =======================================================================================
#
# Epoch :   120     Avg. cost =  0.4090
# Epoch :   121     Avg. cost =  0.5119
# Epoch :   122     Avg. cost =  0.4515
# Epoch :   123     Avg. cost =  0.4765
# Epoch :   124     Avg. cost =  0.4698
# Epoch :   125     Avg. cost =  0.4391
# Epoch :   126     Avg. cost =  0.4580
# Epoch :   127     Avg. cost =  0.4182
# Epoch :   128     Avg. cost =  0.5264
# Epoch :   129     Avg. cost =  0.4330
#
# =======================================================================================
# 000:42:28
# =======================================================================================
#
# Epoch :   130     Avg. cost =  0.4367
# Epoch :   131     Avg. cost =  0.4053
# Epoch :   132     Avg. cost =  0.4260
# Epoch :   133     Avg. cost =  0.4924
# Epoch :   134     Avg. cost =  0.4618
# Epoch :   135     Avg. cost =  0.5017
# Epoch :   136     Avg. cost =  0.4649
# Epoch :   137     Avg. cost =  0.4377
# Epoch :   138     Avg. cost =  0.4500
# Epoch :   139     Avg. cost =  0.4176
#
# =======================================================================================
# 000:45:46
# =======================================================================================
#
# Epoch :   140     Avg. cost =  0.4603
# Epoch :   141     Avg. cost =  0.4530
# Epoch :   142     Avg. cost =  0.4491
# Epoch :   143     Avg. cost =  0.4826
# Epoch :   144     Avg. cost =  0.4521
# Epoch :   145     Avg. cost =  0.4652
# Epoch :   146     Avg. cost =  0.3953
# Epoch :   147     Avg. cost =  0.4496
# Epoch :   148     Avg. cost =  0.4269
# Epoch :   149     Avg. cost =  0.4384
#
# =======================================================================================
# 000:49:04
# =======================================================================================
#
# Epoch :   150     Avg. cost =  0.4433
# Epoch :   151     Avg. cost =  0.4088
# Epoch :   152     Avg. cost =  0.4765
# Epoch :   153     Avg. cost =  0.4697
# Epoch :   154     Avg. cost =  0.4129
# Epoch :   155     Avg. cost =  0.4701
# Epoch :   156     Avg. cost =  0.4370
# Epoch :   157     Avg. cost =  0.4766
# Epoch :   158     Avg. cost =  0.4689
# Epoch :   159     Avg. cost =  0.4145
#
# =======================================================================================
# 000:52:22
# =======================================================================================
#
# Epoch :   160     Avg. cost =  0.5005
# Epoch :   161     Avg. cost =  0.4238
# Epoch :   162     Avg. cost =  0.3926
# Epoch :   163     Avg. cost =  0.4182
# Epoch :   164     Avg. cost =  0.4216
# Epoch :   165     Avg. cost =  0.4169
# Epoch :   166     Avg. cost =  0.3957
# Epoch :   167     Avg. cost =  0.4328
# Epoch :   168     Avg. cost =  0.4241
# Epoch :   169     Avg. cost =  0.4385
#
# =======================================================================================
# 000:55:39
# =======================================================================================
#
# Epoch :   170     Avg. cost =  0.4373
# Epoch :   171     Avg. cost =  0.4839
# Epoch :   172     Avg. cost =  0.4403
# Epoch :   173     Avg. cost =  0.4829
# Epoch :   174     Avg. cost =  0.4276
# Epoch :   175     Avg. cost =  0.4474
# Epoch :   176     Avg. cost =  0.4317
# Epoch :   177     Avg. cost =  0.5129
# Epoch :   178     Avg. cost =  0.4155
# Epoch :   179     Avg. cost =  0.4469
#
# =======================================================================================
# 000:58:57
# =======================================================================================
#
# Epoch :   180     Avg. cost =  0.4404
# Epoch :   181     Avg. cost =  0.4330
# Epoch :   182     Avg. cost =  0.4968
# Epoch :   183     Avg. cost =  0.4443
# Epoch :   184     Avg. cost =  0.4491
# Epoch :   185     Avg. cost =  0.4147
# Epoch :   186     Avg. cost =  0.3869
# Epoch :   187     Avg. cost =  0.4507
# Epoch :   188     Avg. cost =  0.4155
# Epoch :   189     Avg. cost =  0.4361
#
# =======================================================================================
# 001:02:14
# =======================================================================================
#
# Epoch :   190     Avg. cost =  0.4873
# Epoch :   191     Avg. cost =  0.3943
# Epoch :   192     Avg. cost =  0.4554
# Epoch :   193     Avg. cost =  0.3901
# Epoch :   194     Avg. cost =  0.4313
# Epoch :   195     Avg. cost =  0.4111
# Epoch :   196     Avg. cost =  0.4734
# Epoch :   197     Avg. cost =  0.4375
# Epoch :   198     Avg. cost =  0.3901
# Epoch :   199     Avg. cost =  0.4709
#
# =======================================================================================
# 001:05:32
# =======================================================================================
#
# Epoch :   200     Avg. cost =  0.4424
# Epoch :   201     Avg. cost =  0.4418
# Epoch :   202     Avg. cost =  0.4509
# Epoch :   203     Avg. cost =  0.4102
# Epoch :   204     Avg. cost =  0.4368
# Epoch :   205     Avg. cost =  0.4183
# Epoch :   206     Avg. cost =  0.4832
# Epoch :   207     Avg. cost =  0.4100
# Epoch :   208     Avg. cost =  0.4355
# Epoch :   209     Avg. cost =  0.4266
#
# =======================================================================================
# 001:08:50
# =======================================================================================
#
# Epoch :   210     Avg. cost =  0.4876
# Epoch :   211     Avg. cost =  0.3608
# Epoch :   212     Avg. cost =  0.4298
# Epoch :   213     Avg. cost =  0.4153
# Epoch :   214     Avg. cost =  0.3949
# Epoch :   215     Avg. cost =  0.4064
# Epoch :   216     Avg. cost =  0.4194
# Epoch :   217     Avg. cost =  0.4227
# Epoch :   218     Avg. cost =  0.4256
# Epoch :   219     Avg. cost =  0.4422
#
# =======================================================================================
# 001:12:07
# =======================================================================================
#
# Epoch :   220     Avg. cost =  0.4736
# Epoch :   221     Avg. cost =  0.3662
# Epoch :   222     Avg. cost =  0.4108
# Epoch :   223     Avg. cost =  0.3573
# Epoch :   224     Avg. cost =  0.4588
# Epoch :   225     Avg. cost =  0.3655
# Epoch :   226     Avg. cost =  0.3896
# Epoch :   227     Avg. cost =  0.4473
# Epoch :   228     Avg. cost =  0.4333
# Epoch :   229     Avg. cost =  0.4367
#
# =======================================================================================
# 001:15:25
# =======================================================================================
#
# Epoch :   230     Avg. cost =  0.3959
# Epoch :   231     Avg. cost =  0.4193
# Epoch :   232     Avg. cost =  0.3961
# Epoch :   233     Avg. cost =  0.4416
# Epoch :   234     Avg. cost =  0.4581
# Epoch :   235     Avg. cost =  0.4452
# Epoch :   236     Avg. cost =  0.4142
# Epoch :   237     Avg. cost =  0.4336
# Epoch :   238     Avg. cost =  0.4486
# Epoch :   239     Avg. cost =  0.4401
#
# =======================================================================================
# 001:18:43
# =======================================================================================
#
# Epoch :   240     Avg. cost =  0.4124
# Epoch :   241     Avg. cost =  0.4449
# Epoch :   242     Avg. cost =  0.4215
# Epoch :   243     Avg. cost =  0.4105
# Epoch :   244     Avg. cost =  0.4339
# Epoch :   245     Avg. cost =  0.4322
# Epoch :   246     Avg. cost =  0.4411
# Epoch :   247     Avg. cost =  0.4449
# Epoch :   248     Avg. cost =  0.3717
# Epoch :   249     Avg. cost =  0.4244
#
# =======================================================================================
# 001:22:00
# =======================================================================================
#
# Epoch :   250     Avg. cost =  0.4522
# Epoch :   251     Avg. cost =  0.4386
# Epoch :   252     Avg. cost =  0.4270
# Epoch :   253     Avg. cost =  0.4660
# Epoch :   254     Avg. cost =  0.4042
# Epoch :   255     Avg. cost =  0.4064
# Epoch :   256     Avg. cost =  0.4404
# Epoch :   257     Avg. cost =  0.4307
# Epoch :   258     Avg. cost =  0.4264
# Epoch :   259     Avg. cost =  0.4330
#
# =======================================================================================
# 001:25:19
# =======================================================================================
#
# Epoch :   260     Avg. cost =  0.4206
# Epoch :   261     Avg. cost =  0.4305
# Epoch :   262     Avg. cost =  0.4362
# Epoch :   263     Avg. cost =  0.4437
# Epoch :   264     Avg. cost =  0.4246
# Epoch :   265     Avg. cost =  0.4279
# Epoch :   266     Avg. cost =  0.4211
# Epoch :   267     Avg. cost =  0.4618
# Epoch :   268     Avg. cost =  0.4078
# Epoch :   269     Avg. cost =  0.4306
#
# =======================================================================================
# 001:28:37
# =======================================================================================
#
# Epoch :   270     Avg. cost =  0.4132
# Epoch :   271     Avg. cost =  0.4121
# Epoch :   272     Avg. cost =  0.4047
# Epoch :   273     Avg. cost =  0.4036
# Epoch :   274     Avg. cost =  0.3817
# Epoch :   275     Avg. cost =  0.4180
# Epoch :   276     Avg. cost =  0.4483
# Epoch :   277     Avg. cost =  0.4052
# Epoch :   278     Avg. cost =  0.4334
# Epoch :   279     Avg. cost =  0.4161
#
# =======================================================================================
# 001:31:55
# =======================================================================================
#
# Epoch :   280     Avg. cost =  0.3908
# Epoch :   281     Avg. cost =  0.3967
# Epoch :   282     Avg. cost =  0.4136
# Epoch :   283     Avg. cost =  0.3986
# Epoch :   284     Avg. cost =  0.4210
# Epoch :   285     Avg. cost =  0.3442
# Epoch :   286     Avg. cost =  0.3534
# Epoch :   287     Avg. cost =  0.4051
# Epoch :   288     Avg. cost =  0.3871
# Epoch :   289     Avg. cost =  0.4291
#
# =======================================================================================
# 001:35:13
# =======================================================================================
# Epoch :   290     Avg. cost =  0.3881
# Epoch :   291     Avg. cost =  0.3755
# Epoch :   292     Avg. cost =  0.4139
# Epoch :   293     Avg. cost =  0.4544
# Epoch :   294     Avg. cost =  0.4348
# Epoch :   295     Avg. cost =  0.3764
# Epoch :   296     Avg. cost =  0.3635
# Epoch :   297     Avg. cost =  0.4302
# Epoch :   298     Avg. cost =  0.4310
# Epoch :   299     Avg. cost =  0.4517
#
# =======================================================================================
# 001:38:32
# =======================================================================================
#
# Epoch :   300     Avg. cost =  0.4369
# Epoch :   301     Avg. cost =  0.4415
# Epoch :   302     Avg. cost =  0.3477
# Epoch :   303     Avg. cost =  0.3843
# Epoch :   304     Avg. cost =  0.4202
# Epoch :   305     Avg. cost =  0.4156
# Epoch :   306     Avg. cost =  0.3958
# Epoch :   307     Avg. cost =  0.4398
# Epoch :   308     Avg. cost =  0.3829
# Epoch :   309     Avg. cost =  0.3520
#
# =======================================================================================
# 001:41:50
# =======================================================================================
#
# Epoch :   310     Avg. cost =  0.3791
# Epoch :   311     Avg. cost =  0.4424
# Epoch :   312     Avg. cost =  0.3927
# Epoch :   313     Avg. cost =  0.3925
# Epoch :   314     Avg. cost =  0.4036
# Epoch :   315     Avg. cost =  0.3673
# Epoch :   316     Avg. cost =  0.3743
# Epoch :   317     Avg. cost =  0.3949
# Epoch :   318     Avg. cost =  0.4262
# Epoch :   319     Avg. cost =  0.3956
#
# =======================================================================================
# 001:45:08
# =======================================================================================
#
# Epoch :   320     Avg. cost =  0.4094
# Epoch :   321     Avg. cost =  0.3901
# Epoch :   322     Avg. cost =  0.3891
# Epoch :   323     Avg. cost =  0.3695
# Epoch :   324     Avg. cost =  0.3785
# Epoch :   325     Avg. cost =  0.4194
# Epoch :   326     Avg. cost =  0.4146
# Epoch :   327     Avg. cost =  0.4329
# Epoch :   328     Avg. cost =  0.4002
# Epoch :   329     Avg. cost =  0.4008
#
# =======================================================================================
# 001:48:26
# =======================================================================================
#
# Epoch :   330     Avg. cost =  0.4037
# Epoch :   331     Avg. cost =  0.4153
# Epoch :   332     Avg. cost =  0.4131
# Epoch :   333     Avg. cost =  0.4387
# Epoch :   334     Avg. cost =  0.3872
# Epoch :   335     Avg. cost =  0.3925
# Epoch :   336     Avg. cost =  0.3785
# Epoch :   337     Avg. cost =  0.4436
# Epoch :   338     Avg. cost =  0.3457
# Epoch :   339     Avg. cost =  0.3564
#
# =======================================================================================
# 001:51:44
# =======================================================================================
#
# Epoch :   340     Avg. cost =  0.4474
# Epoch :   341     Avg. cost =  0.4114
# Epoch :   342     Avg. cost =  0.3890
# Epoch :   343     Avg. cost =  0.4242
# Epoch :   344     Avg. cost =  0.4330
# Epoch :   345     Avg. cost =  0.3552
# Epoch :   346     Avg. cost =  0.4334
# Epoch :   347     Avg. cost =  0.3660
# Epoch :   348     Avg. cost =  0.4203
# Epoch :   349     Avg. cost =  0.4071
#
# =======================================================================================
# 001:55:02
# =======================================================================================
#
# Epoch :   350     Avg. cost =  0.3810
# Epoch :   351     Avg. cost =  0.3787
# Epoch :   352     Avg. cost =  0.3782
# Epoch :   353     Avg. cost =  0.4019
# Epoch :   354     Avg. cost =  0.4136
# Epoch :   355     Avg. cost =  0.3796
# Epoch :   356     Avg. cost =  0.4153
# Epoch :   357     Avg. cost =  0.3963
# Epoch :   358     Avg. cost =  0.4580
# Epoch :   359     Avg. cost =  0.3625
#
# =======================================================================================
# 001:58:19
# =======================================================================================
#
# Epoch :   360     Avg. cost =  0.3950
# Epoch :   361     Avg. cost =  0.3692
# Epoch :   362     Avg. cost =  0.4192
# Epoch :   363     Avg. cost =  0.3835
# Epoch :   364     Avg. cost =  0.3586
# Epoch :   365     Avg. cost =  0.4198
# Epoch :   366     Avg. cost =  0.3722
# Epoch :   367     Avg. cost =  0.3650
# Epoch :   368     Avg. cost =  0.3858
# Epoch :   369     Avg. cost =  0.4099
#
# =======================================================================================
# 002:01:38
# =======================================================================================
#
# Epoch :   370     Avg. cost =  0.4033
# Epoch :   371     Avg. cost =  0.3779
# Epoch :   372     Avg. cost =  0.4110
# Epoch :   373     Avg. cost =  0.3823
# Epoch :   374     Avg. cost =  0.4004
# Epoch :   375     Avg. cost =  0.3705
# Epoch :   376     Avg. cost =  0.3899
# Epoch :   377     Avg. cost =  0.3276
# Epoch :   378     Avg. cost =  0.3535
# Epoch :   379     Avg. cost =  0.4042
#
# =======================================================================================
# 002:04:56
# =======================================================================================
#
# Epoch :   380     Avg. cost =  0.3659
# Epoch :   381     Avg. cost =  0.3898
# Epoch :   382     Avg. cost =  0.3725
# Epoch :   383     Avg. cost =  0.4041
# Epoch :   384     Avg. cost =  0.3509
# Epoch :   385     Avg. cost =  0.4279
# Epoch :   386     Avg. cost =  0.3634
# Epoch :   387     Avg. cost =  0.3640
# Epoch :   388     Avg. cost =  0.3986
# Epoch :   389     Avg. cost =  0.4354
#
# =======================================================================================
# 002:08:14
# =======================================================================================
#
# Epoch :   390     Avg. cost =  0.4034
# Epoch :   391     Avg. cost =  0.3907
# Epoch :   392     Avg. cost =  0.4134
# Epoch :   393     Avg. cost =  0.3682
# Epoch :   394     Avg. cost =  0.3990
# Epoch :   395     Avg. cost =  0.3992
# Epoch :   396     Avg. cost =  0.3807
# Epoch :   397     Avg. cost =  0.3953
# Epoch :   398     Avg. cost =  0.3251
# Epoch :   399     Avg. cost =  0.3548
#
# =======================================================================================
# 002:11:33
# =======================================================================================
#
# Epoch :   400     Avg. cost =  0.3732
# Epoch :   401     Avg. cost =  0.4045
# Epoch :   402     Avg. cost =  0.3563
# Epoch :   403     Avg. cost =  0.3502
# Epoch :   404     Avg. cost =  0.3848
# Epoch :   405     Avg. cost =  0.3723
# Epoch :   406     Avg. cost =  0.4292
# Epoch :   407     Avg. cost =  0.4121
# Epoch :   408     Avg. cost =  0.3463
# Epoch :   409     Avg. cost =  0.3482
#
# =======================================================================================
# 002:14:51
# =======================================================================================
#
# Epoch :   410     Avg. cost =  0.4270
# Epoch :   411     Avg. cost =  0.3753
# Epoch :   412     Avg. cost =  0.3985
# Epoch :   413     Avg. cost =  0.4088
# Epoch :   414     Avg. cost =  0.3352
# Epoch :   415     Avg. cost =  0.4016
# Epoch :   416     Avg. cost =  0.3976
# Epoch :   417     Avg. cost =  0.3223
# Epoch :   418     Avg. cost =  0.4241
# Epoch :   419     Avg. cost =  0.3629
#
# =======================================================================================
# 002:18:09
# =======================================================================================
#
# Epoch :   420     Avg. cost =  0.3682
# Epoch :   421     Avg. cost =  0.3470
# Epoch :   422     Avg. cost =  0.3644
# Epoch :   423     Avg. cost =  0.3726
# Epoch :   424     Avg. cost =  0.3777
# Epoch :   425     Avg. cost =  0.4285
# Epoch :   426     Avg. cost =  0.3873
# Epoch :   427     Avg. cost =  0.3552
# Epoch :   428     Avg. cost =  0.3548
# Epoch :   429     Avg. cost =  0.3505
#
# =======================================================================================
# 002:21:27
# =======================================================================================
#
# Epoch :   430     Avg. cost =  0.3756
# Epoch :   431     Avg. cost =  0.3836
# Epoch :   432     Avg. cost =  0.3502
# Epoch :   433     Avg. cost =  0.3588
# Epoch :   434     Avg. cost =  0.3870
# Epoch :   435     Avg. cost =  0.3909
# Epoch :   436     Avg. cost =  0.4345
# Epoch :   437     Avg. cost =  0.3702
# Epoch :   438     Avg. cost =  0.4156
# Epoch :   439     Avg. cost =  0.3557
#
# =======================================================================================
# 002:24:46
# =======================================================================================
#
# Epoch :   440     Avg. cost =  0.3594
# Epoch :   441     Avg. cost =  0.3426
# Epoch :   442     Avg. cost =  0.3746
# Epoch :   443     Avg. cost =  0.3981
# Epoch :   444     Avg. cost =  0.3609
# Epoch :   445     Avg. cost =  0.3763
# Epoch :   446     Avg. cost =  0.3599
# Epoch :   447     Avg. cost =  0.3735
# Epoch :   448     Avg. cost =  0.4334
# Epoch :   449     Avg. cost =  0.3531
#
# =======================================================================================
# 002:28:04
# =======================================================================================
#
# Epoch :   450     Avg. cost =  0.3845
# Epoch :   451     Avg. cost =  0.4070
# Epoch :   452     Avg. cost =  0.3673
# Epoch :   453     Avg. cost =  0.4235
# Epoch :   454     Avg. cost =  0.3696
# Epoch :   455     Avg. cost =  0.3708
# Epoch :   456     Avg. cost =  0.3925
# Epoch :   457     Avg. cost =  0.4181
# Epoch :   458     Avg. cost =  0.3855
# Epoch :   459     Avg. cost =  0.4124
#
# =======================================================================================
# 002:31:22
# =======================================================================================
#
# Epoch :   460     Avg. cost =  0.3390
# Epoch :   461     Avg. cost =  0.3613
# Epoch :   462     Avg. cost =  0.4105
# Epoch :   463     Avg. cost =  0.3805
# Epoch :   464     Avg. cost =  0.3723
# Epoch :   465     Avg. cost =  0.3658
# Epoch :   466     Avg. cost =  0.3634
# Epoch :   467     Avg. cost =  0.3441
# Epoch :   468     Avg. cost =  0.3984
# Epoch :   469     Avg. cost =  0.3415
#
# =======================================================================================
# 002:34:40
# =======================================================================================
#
# Epoch :   470     Avg. cost =  0.3962
# Epoch :   471     Avg. cost =  0.3739
# Epoch :   472     Avg. cost =  0.3528
# Epoch :   473     Avg. cost =  0.3831
# Epoch :   474     Avg. cost =  0.3984
# Epoch :   475     Avg. cost =  0.3516
# Epoch :   476     Avg. cost =  0.3971
# Epoch :   477     Avg. cost =  0.3370
# Epoch :   478     Avg. cost =  0.4159
# Epoch :   479     Avg. cost =  0.4138
#
# =======================================================================================
# 002:37:59
# =======================================================================================
#
# Epoch :   480     Avg. cost =  0.3853
# Epoch :   481     Avg. cost =  0.3354
# Epoch :   482     Avg. cost =  0.3470
# Epoch :   483     Avg. cost =  0.3763
# Epoch :   484     Avg. cost =  0.2975
# Epoch :   485     Avg. cost =  0.4212
# Epoch :   486     Avg. cost =  0.3559
# Epoch :   487     Avg. cost =  0.2947
# Epoch :   488     Avg. cost =  0.3557
# Epoch :   489     Avg. cost =  0.3494
#
# =======================================================================================
# 002:41:17
# =======================================================================================
#
# Epoch :   490     Avg. cost =  0.3628
# Epoch :   491     Avg. cost =  0.3602
# Epoch :   492     Avg. cost =  0.3176
# Epoch :   493     Avg. cost =  0.3446
# Epoch :   494     Avg. cost =  0.3837
# Epoch :   495     Avg. cost =  0.3476
# Epoch :   496     Avg. cost =  0.4038
# Epoch :   497     Avg. cost =  0.3963
# Epoch :   498     Avg. cost =  0.4023
# Epoch :   499     Avg. cost =  0.4146
#
# =======================================================================================
# 002:44:35
# =======================================================================================
#
# Epoch :   500     Avg. cost =  0.3511
#
# =======================================================================================
# ================================     Training done     ================================
# =======================================================================================
#
# n:  0     label_input:  [0]     label_output:  [0]
# n:  1     label_input:  [0]     label_output:  [0]
# n:  2     label_input:  [0]     label_output:  [0]
# n:  3     label_input:  [0]     label_output:  [0]
# n:  4     label_input:  [0]     label_output:  [0]
# n:  5     label_input:  [0]     label_output:  [0]
# n:  6     label_input:  [0]     label_output:  [0]
# n:  7     label_input:  [0]     label_output:  [0]
# n:  8     label_input:  [0]     label_output:  [0]
# n:  9     label_input:  [0]     label_output:  [0]
# n:  10     label_input:  [0]     label_output:  [0]
# n:  11     label_input:  [0]     label_output:  [0]
# n:  12     label_input:  [0]     label_output:  [0]
# n:  13     label_input:  [0]     label_output:  [0]
# n:  14     label_input:  [0]     label_output:  [0]
# n:  15     label_input:  [0]     label_output:  [0]
# n:  16     label_input:  [0]     label_output:  [0]
# n:  17     label_input:  [0]     label_output:  [0]
# n:  18     label_input:  [0]     label_output:  [0]
# n:  19     label_input:  [0]     label_output:  [0]
# n:  20     label_input:  [0]     label_output:  [0]
# n:  21     label_input:  [0]     label_output:  [0]
# n:  22     label_input:  [0]     label_output:  [0]
# n:  23     label_input:  [0]     label_output:  [0]
# n:  24     label_input:  [0]     label_output:  [0]
# n:  25     label_input:  [0]     label_output:  [0]
# n:  26     label_input:  [0]     label_output:  [0]
# n:  27     label_input:  [0]     label_output:  [0]
# n:  28     label_input:  [0]     label_output:  [0]
# n:  29     label_input:  [0]     label_output:  [0]
# n:  30     label_input:  [0]     label_output:  [0]
# n:  31     label_input:  [0]     label_output:  [0]
# n:  32     label_input:  [0]     label_output:  [0]
# n:  33     label_input:  [0]     label_output:  [0]
# n:  34     label_input:  [0]     label_output:  [0]
# n:  35     label_input:  [0]     label_output:  [0]
# n:  36     label_input:  [0]     label_output:  [0]
# n:  37     label_input:  [0]     label_output:  [0]
# n:  38     label_input:  [0]     label_output:  [0]
# n:  39     label_input:  [0]     label_output:  [0]
# n:  40     label_input:  [0]     label_output:  [0]
# n:  41     label_input:  [0]     label_output:  [0]
# n:  42     label_input:  [0]     label_output:  [0]
# n:  43     label_input:  [0]     label_output:  [0]
# n:  44     label_input:  [0]     label_output:  [0]
# n:  45     label_input:  [0]     label_output:  [0]
# n:  46     label_input:  [0]     label_output:  [0]
# n:  47     label_input:  [0]     label_output:  [0]
# n:  48     label_input:  [0]     label_output:  [0]
# n:  49     label_input:  [0]     label_output:  [1]
# n:  50     label_input:  [0]     label_output:  [0]
# n:  51     label_input:  [0]     label_output:  [0]
# n:  52     label_input:  [0]     label_output:  [0]
# n:  53     label_input:  [0]     label_output:  [0]
# n:  54     label_input:  [0]     label_output:  [0]
# n:  55     label_input:  [0]     label_output:  [0]
# n:  56     label_input:  [0]     label_output:  [0]
# n:  57     label_input:  [0]     label_output:  [0]
# n:  58     label_input:  [0]     label_output:  [0]
# n:  59     label_input:  [0]     label_output:  [0]
# n:  60     label_input:  [0]     label_output:  [0]
# n:  61     label_input:  [0]     label_output:  [0]
# n:  62     label_input:  [0]     label_output:  [0]
# n:  63     label_input:  [0]     label_output:  [0]
# n:  64     label_input:  [0]     label_output:  [0]
# n:  65     label_input:  [0]     label_output:  [0]
# n:  66     label_input:  [0]     label_output:  [1]
# n:  67     label_input:  [0]     label_output:  [0]
# n:  68     label_input:  [0]     label_output:  [0]
# n:  69     label_input:  [0]     label_output:  [0]
# n:  70     label_input:  [0]     label_output:  [0]
# n:  71     label_input:  [0]     label_output:  [0]
# n:  72     label_input:  [0]     label_output:  [0]
# n:  73     label_input:  [0]     label_output:  [0]
# n:  74     label_input:  [0]     label_output:  [0]
# n:  75     label_input:  [0]     label_output:  [0]
# n:  76     label_input:  [0]     label_output:  [0]
# n:  77     label_input:  [0]     label_output:  [0]
# n:  78     label_input:  [0]     label_output:  [0]
# n:  79     label_input:  [0]     label_output:  [0]
# n:  80     label_input:  [0]     label_output:  [0]
# n:  81     label_input:  [0]     label_output:  [0]
# n:  82     label_input:  [0]     label_output:  [0]
# n:  83     label_input:  [0]     label_output:  [0]
# n:  84     label_input:  [0]     label_output:  [0]
# n:  85     label_input:  [0]     label_output:  [0]
# n:  86     label_input:  [0]     label_output:  [0]
# n:  87     label_input:  [0]     label_output:  [0]
# n:  88     label_input:  [0]     label_output:  [0]
# n:  89     label_input:  [0]     label_output:  [0]
# n:  90     label_input:  [0]     label_output:  [0]
# n:  91     label_input:  [0]     label_output:  [0]
# n:  92     label_input:  [0]     label_output:  [0]
# n:  93     label_input:  [0]     label_output:  [1]
# n:  94     label_input:  [0]     label_output:  [0]
# n:  95     label_input:  [0]     label_output:  [0]
# n:  96     label_input:  [0]     label_output:  [0]
# n:  97     label_input:  [0]     label_output:  [0]
# n:  98     label_input:  [0]     label_output:  [0]
# n:  99     label_input:  [0]     label_output:  [0]
# n:  100     label_input:  [0]     label_output:  [0]
# n:  101     label_input:  [0]     label_output:  [0]
# n:  102     label_input:  [0]     label_output:  [0]
# n:  103     label_input:  [0]     label_output:  [0]
# n:  104     label_input:  [0]     label_output:  [0]
# n:  105     label_input:  [0]     label_output:  [0]
# n:  106     label_input:  [0]     label_output:  [0]
# n:  107     label_input:  [0]     label_output:  [1]
# n:  108     label_input:  [0]     label_output:  [0]
# n:  109     label_input:  [0]     label_output:  [0]
# n:  110     label_input:  [0]     label_output:  [0]
# n:  111     label_input:  [0]     label_output:  [0]
# n:  112     label_input:  [0]     label_output:  [0]
# n:  113     label_input:  [0]     label_output:  [0]
# n:  114     label_input:  [0]     label_output:  [0]
# n:  115     label_input:  [0]     label_output:  [0]
# n:  116     label_input:  [0]     label_output:  [0]
# n:  117     label_input:  [0]     label_output:  [0]
# n:  118     label_input:  [0]     label_output:  [0]
# n:  119     label_input:  [0]     label_output:  [1]
# n:  120     label_input:  [0]     label_output:  [0]
# n:  121     label_input:  [0]     label_output:  [0]
# n:  122     label_input:  [0]     label_output:  [0]
# n:  123     label_input:  [0]     label_output:  [0]
# n:  124     label_input:  [0]     label_output:  [0]
# n:  125     label_input:  [0]     label_output:  [0]
# n:  126     label_input:  [0]     label_output:  [0]
# n:  127     label_input:  [0]     label_output:  [0]
# n:  128     label_input:  [0]     label_output:  [0]
# n:  129     label_input:  [0]     label_output:  [0]
# n:  130     label_input:  [0]     label_output:  [0]
# n:  131     label_input:  [0]     label_output:  [0]
# n:  132     label_input:  [0]     label_output:  [0]
# n:  133     label_input:  [0]     label_output:  [0]
# n:  134     label_input:  [0]     label_output:  [0]
# n:  135     label_input:  [0]     label_output:  [0]
# n:  136     label_input:  [0]     label_output:  [1]
# n:  137     label_input:  [0]     label_output:  [0]
# n:  138     label_input:  [0]     label_output:  [0]
# n:  139     label_input:  [0]     label_output:  [0]
# n:  140     label_input:  [0]     label_output:  [0]
# n:  141     label_input:  [0]     label_output:  [0]
# n:  142     label_input:  [0]     label_output:  [0]
# n:  143     label_input:  [0]     label_output:  [0]
# n:  144     label_input:  [0]     label_output:  [0]
# n:  145     label_input:  [0]     label_output:  [0]
# n:  146     label_input:  [0]     label_output:  [0]
# n:  147     label_input:  [0]     label_output:  [0]
# n:  148     label_input:  [0]     label_output:  [0]
# n:  149     label_input:  [0]     label_output:  [0]
# n:  150     label_input:  [0]     label_output:  [0]
# n:  151     label_input:  [0]     label_output:  [1]
# n:  152     label_input:  [0]     label_output:  [0]
# n:  153     label_input:  [0]     label_output:  [0]
# n:  154     label_input:  [0]     label_output:  [1]
# n:  155     label_input:  [0]     label_output:  [0]
# n:  156     label_input:  [0]     label_output:  [0]
# n:  157     label_input:  [0]     label_output:  [0]
# n:  158     label_input:  [0]     label_output:  [0]
# n:  159     label_input:  [0]     label_output:  [0]
# n:  160     label_input:  [0]     label_output:  [1]
# n:  161     label_input:  [0]     label_output:  [0]
# n:  162     label_input:  [0]     label_output:  [0]
# n:  163     label_input:  [0]     label_output:  [1]
# n:  164     label_input:  [0]     label_output:  [0]
# n:  165     label_input:  [0]     label_output:  [0]
# n:  166     label_input:  [0]     label_output:  [0]
# n:  167     label_input:  [0]     label_output:  [0]
# n:  168     label_input:  [0]     label_output:  [0]
# n:  169     label_input:  [0]     label_output:  [0]
# n:  170     label_input:  [0]     label_output:  [0]
# n:  171     label_input:  [0]     label_output:  [0]
# n:  172     label_input:  [0]     label_output:  [1]
# n:  173     label_input:  [0]     label_output:  [1]
# n:  174     label_input:  [0]     label_output:  [0]
# n:  175     label_input:  [0]     label_output:  [0]
# n:  176     label_input:  [0]     label_output:  [0]
# n:  177     label_input:  [0]     label_output:  [0]
# n:  178     label_input:  [0]     label_output:  [0]
# n:  179     label_input:  [0]     label_output:  [0]
# n:  180     label_input:  [0]     label_output:  [0]
# n:  181     label_input:  [0]     label_output:  [0]
# n:  182     label_input:  [0]     label_output:  [0]
# n:  183     label_input:  [0]     label_output:  [0]
# n:  184     label_input:  [0]     label_output:  [0]
# n:  185     label_input:  [0]     label_output:  [0]
# n:  186     label_input:  [0]     label_output:  [0]
# n:  187     label_input:  [0]     label_output:  [0]
# n:  188     label_input:  [0]     label_output:  [0]
# n:  189     label_input:  [0]     label_output:  [0]
# n:  190     label_input:  [0]     label_output:  [0]
# n:  191     label_input:  [0]     label_output:  [0]
# n:  192     label_input:  [0]     label_output:  [0]
# n:  193     label_input:  [0]     label_output:  [0]
# n:  194     label_input:  [0]     label_output:  [0]
# n:  195     label_input:  [0]     label_output:  [0]
# n:  196     label_input:  [0]     label_output:  [0]
# n:  197     label_input:  [0]     label_output:  [0]
# n:  198     label_input:  [0]     label_output:  [0]
# n:  199     label_input:  [0]     label_output:  [0]
# n:  200     label_input:  [0]     label_output:  [0]
# n:  201     label_input:  [0]     label_output:  [0]
# n:  202     label_input:  [0]     label_output:  [0]
# n:  203     label_input:  [0]     label_output:  [0]
# n:  204     label_input:  [0]     label_output:  [1]
# n:  205     label_input:  [0]     label_output:  [0]
# n:  206     label_input:  [0]     label_output:  [0]
# n:  207     label_input:  [0]     label_output:  [0]
# n:  208     label_input:  [0]     label_output:  [0]
# n:  209     label_input:  [0]     label_output:  [0]
# n:  210     label_input:  [0]     label_output:  [0]
# n:  211     label_input:  [0]     label_output:  [0]
# n:  212     label_input:  [0]     label_output:  [0]
# n:  213     label_input:  [0]     label_output:  [0]
# n:  214     label_input:  [0]     label_output:  [0]
# n:  215     label_input:  [0]     label_output:  [0]
# n:  216     label_input:  [0]     label_output:  [0]
# n:  217     label_input:  [0]     label_output:  [0]
# n:  218     label_input:  [0]     label_output:  [0]
# n:  219     label_input:  [0]     label_output:  [0]
# n:  220     label_input:  [0]     label_output:  [2]
# n:  221     label_input:  [0]     label_output:  [0]
# n:  222     label_input:  [0]     label_output:  [0]
# n:  223     label_input:  [0]     label_output:  [1]
# n:  224     label_input:  [0]     label_output:  [0]
# n:  225     label_input:  [0]     label_output:  [0]
# n:  226     label_input:  [0]     label_output:  [0]
# n:  227     label_input:  [0]     label_output:  [0]
# n:  228     label_input:  [0]     label_output:  [0]
# n:  229     label_input:  [0]     label_output:  [0]
# n:  230     label_input:  [0]     label_output:  [0]
# n:  231     label_input:  [0]     label_output:  [0]
# n:  232     label_input:  [0]     label_output:  [1]
# n:  233     label_input:  [0]     label_output:  [0]
# n:  234     label_input:  [0]     label_output:  [0]
# n:  235     label_input:  [0]     label_output:  [0]
# n:  236     label_input:  [0]     label_output:  [0]
# n:  237     label_input:  [0]     label_output:  [0]
# n:  238     label_input:  [0]     label_output:  [0]
# n:  239     label_input:  [0]     label_output:  [0]
# n:  240     label_input:  [0]     label_output:  [0]
# n:  241     label_input:  [0]     label_output:  [0]
# n:  242     label_input:  [0]     label_output:  [0]
# n:  243     label_input:  [0]     label_output:  [0]
# n:  244     label_input:  [0]     label_output:  [1]
# n:  245     label_input:  [0]     label_output:  [0]
# n:  246     label_input:  [0]     label_output:  [0]
# n:  247     label_input:  [0]     label_output:  [0]
# n:  248     label_input:  [0]     label_output:  [0]
# n:  249     label_input:  [0]     label_output:  [0]
# n:  250     label_input:  [0]     label_output:  [0]
# n:  251     label_input:  [0]     label_output:  [0]
# n:  252     label_input:  [0]     label_output:  [0]
# n:  253     label_input:  [0]     label_output:  [1]
# n:  254     label_input:  [0]     label_output:  [0]
# n:  255     label_input:  [0]     label_output:  [0]
# n:  256     label_input:  [0]     label_output:  [0]
# n:  257     label_input:  [0]     label_output:  [1]
# n:  258     label_input:  [0]     label_output:  [0]
# n:  259     label_input:  [0]     label_output:  [0]
# n:  260     label_input:  [0]     label_output:  [0]
# n:  261     label_input:  [0]     label_output:  [0]
# n:  262     label_input:  [0]     label_output:  [0]
# n:  263     label_input:  [0]     label_output:  [0]
# n:  264     label_input:  [0]     label_output:  [1]
# n:  265     label_input:  [0]     label_output:  [0]
# n:  266     label_input:  [0]     label_output:  [0]
# n:  267     label_input:  [0]     label_output:  [0]
# n:  268     label_input:  [0]     label_output:  [0]
# n:  269     label_input:  [0]     label_output:  [1]
# n:  270     label_input:  [0]     label_output:  [0]
# n:  271     label_input:  [0]     label_output:  [0]
# n:  272     label_input:  [0]     label_output:  [0]
# n:  273     label_input:  [0]     label_output:  [0]
# n:  274     label_input:  [0]     label_output:  [1]
# n:  275     label_input:  [0]     label_output:  [0]
# n:  276     label_input:  [0]     label_output:  [0]
# n:  277     label_input:  [0]     label_output:  [1]
# n:  278     label_input:  [0]     label_output:  [0]
# n:  279     label_input:  [0]     label_output:  [0]
# n:  280     label_input:  [0]     label_output:  [0]
# n:  281     label_input:  [0]     label_output:  [0]
# n:  282     label_input:  [0]     label_output:  [0]
# n:  283     label_input:  [0]     label_output:  [1]
# n:  284     label_input:  [0]     label_output:  [0]
# n:  285     label_input:  [0]     label_output:  [0]
# n:  286     label_input:  [0]     label_output:  [1]
# n:  287     label_input:  [0]     label_output:  [1]
# n:  288     label_input:  [0]     label_output:  [0]
# n:  289     label_input:  [0]     label_output:  [0]
# n:  290     label_input:  [0]     label_output:  [0]
# n:  291     label_input:  [0]     label_output:  [1]
# n:  292     label_input:  [0]     label_output:  [0]
# n:  293     label_input:  [0]     label_output:  [0]
# n:  294     label_input:  [0]     label_output:  [0]
# n:  295     label_input:  [0]     label_output:  [0]
# n:  296     label_input:  [0]     label_output:  [0]
# n:  297     label_input:  [0]     label_output:  [1]
# n:  298     label_input:  [0]     label_output:  [0]
# n:  299     label_input:  [0]     label_output:  [0]
# n:  300     label_input:  [0]     label_output:  [0]
# n:  301     label_input:  [0]     label_output:  [0]
# n:  302     label_input:  [0]     label_output:  [0]
# n:  303     label_input:  [0]     label_output:  [0]
# n:  304     label_input:  [0]     label_output:  [0]
# n:  305     label_input:  [0]     label_output:  [0]
# n:  306     label_input:  [0]     label_output:  [0]
# n:  307     label_input:  [0]     label_output:  [0]
# n:  308     label_input:  [0]     label_output:  [0]
# n:  309     label_input:  [0]     label_output:  [0]
# n:  310     label_input:  [0]     label_output:  [0]
# n:  311     label_input:  [0]     label_output:  [1]
# n:  312     label_input:  [0]     label_output:  [0]
# n:  313     label_input:  [0]     label_output:  [0]
# n:  314     label_input:  [0]     label_output:  [1]
# n:  315     label_input:  [0]     label_output:  [0]
# n:  316     label_input:  [0]     label_output:  [0]
# n:  317     label_input:  [0]     label_output:  [0]
# n:  318     label_input:  [0]     label_output:  [0]
# n:  319     label_input:  [0]     label_output:  [0]
# n:  320     label_input:  [0]     label_output:  [0]
# n:  321     label_input:  [0]     label_output:  [0]
# n:  322     label_input:  [0]     label_output:  [0]
# n:  323     label_input:  [0]     label_output:  [0]
# n:  324     label_input:  [0]     label_output:  [0]
# n:  325     label_input:  [0]     label_output:  [1]
# n:  326     label_input:  [0]     label_output:  [0]
# n:  327     label_input:  [0]     label_output:  [2]
# n:  328     label_input:  [0]     label_output:  [0]
# n:  329     label_input:  [0]     label_output:  [0]
# n:  330     label_input:  [0]     label_output:  [0]
# n:  331     label_input:  [0]     label_output:  [0]
# n:  332     label_input:  [0]     label_output:  [0]
# n:  333     label_input:  [0]     label_output:  [0]
# n:  334     label_input:  [0]     label_output:  [0]
# n:  335     label_input:  [0]     label_output:  [0]
# n:  336     label_input:  [0]     label_output:  [0]
# n:  337     label_input:  [0]     label_output:  [0]
# n:  338     label_input:  [0]     label_output:  [0]
# n:  339     label_input:  [0]     label_output:  [0]
# n:  340     label_input:  [0]     label_output:  [0]
# n:  341     label_input:  [0]     label_output:  [0]
# n:  342     label_input:  [0]     label_output:  [0]
# n:  343     label_input:  [0]     label_output:  [0]
# n:  344     label_input:  [0]     label_output:  [1]
# n:  345     label_input:  [0]     label_output:  [1]
# n:  346     label_input:  [0]     label_output:  [0]
# n:  347     label_input:  [0]     label_output:  [0]
# n:  348     label_input:  [0]     label_output:  [0]
# n:  349     label_input:  [1]     label_output:  [1]
# n:  350     label_input:  [1]     label_output:  [1]
# n:  351     label_input:  [1]     label_output:  [2]
# n:  352     label_input:  [1]     label_output:  [1]
# n:  353     label_input:  [1]     label_output:  [1]
# n:  354     label_input:  [1]     label_output:  [1]
# n:  355     label_input:  [1]     label_output:  [1]
# n:  356     label_input:  [1]     label_output:  [1]
# ...
# n:  797     label_input:  [2]     label_output:  [1]
# n:  798     label_input:  [2]     label_output:  [2]
# n:  799     label_input:  [2]     label_output:  [2]
# n:  800     label_input:  [2]     label_output:  [2]
# n:  801     label_input:  [2]     label_output:  [2]
# n:  802     label_input:  [2]     label_output:  [2]
# n:  803     label_input:  [2]     label_output:  [2]
# n:  804     label_input:  [2]     label_output:  [2]
# n:  805     label_input:  [2]     label_output:  [2]
# n:  806     label_input:  [2]     label_output:  [2]
# n:  807     label_input:  [2]     label_output:  [2]
# n:  808     label_input:  [2]     label_output:  [2]
# n:  809     label_input:  [2]     label_output:  [2]
# n:  810     label_input:  [2]     label_output:  [2]
# n:  811     label_input:  [2]     label_output:  [2]
# n:  812     label_input:  [2]     label_output:  [2]
# n:  813     label_input:  [2]     label_output:  [2]
# n:  814     label_input:  [2]     label_output:  [1]
# n:  815     label_input:  [2]     label_output:  [2]
# n:  816     label_input:  [2]     label_output:  [2]
# n:  817     label_input:  [2]     label_output:  [0]
# n:  818     label_input:  [2]     label_output:  [2]
# n:  819     label_input:  [2]     label_output:  [2]
# n:  820     label_input:  [2]     label_output:  [2]
# n:  821     label_input:  [2]     label_output:  [2]
# n:  822     label_input:  [2]     label_output:  [2]
# n:  823     label_input:  [2]     label_output:  [2]
# n:  824     label_input:  [2]     label_output:  [2]
# n:  825     label_input:  [2]     label_output:  [2]
# n:  826     label_input:  [2]     label_output:  [2]
# n:  827     label_input:  [2]     label_output:  [2]
# n:  828     label_input:  [2]     label_output:  [2]
# n:  829     label_input:  [2]     label_output:  [2]
# n:  830     label_input:  [2]     label_output:  [2]
# n:  831     label_input:  [2]     label_output:  [2]
# n:  832     label_input:  [2]     label_output:  [2]
# n:  833     label_input:  [2]     label_output:  [2]
# n:  834     label_input:  [2]     label_output:  [2]
# n:  835     label_input:  [2]     label_output:  [2]
# n:  836     label_input:  [2]     label_output:  [2]
# n:  837     label_input:  [2]     label_output:  [2]
# n:  838     label_input:  [2]     label_output:  [2]
# n:  839     label_input:  [2]     label_output:  [2]
# n:  840     label_input:  [2]     label_output:  [2]
# n:  841     label_input:  [2]     label_output:  [2]
# n:  842     label_input:  [2]     label_output:  [1]
# n:  843     label_input:  [2]     label_output:  [2]
# n:  844     label_input:  [2]     label_output:  [2]
# n:  845     label_input:  [2]     label_output:  [2]
# n:  846     label_input:  [2]     label_output:  [2]
# n:  847     label_input:  [2]     label_output:  [2]
# n:  848     label_input:  [2]     label_output:  [0]
# n:  849     label_input:  [2]     label_output:  [0]
# n:  850     label_input:  [2]     label_output:  [2]
# n:  851     label_input:  [2]     label_output:  [2]
# n:  852     label_input:  [2]     label_output:  [2]
# n:  853     label_input:  [2]     label_output:  [2]
# n:  854     label_input:  [2]     label_output:  [2]
# n:  855     label_input:  [2]     label_output:  [2]
# n:  856     label_input:  [2]     label_output:  [2]
# n:  857     label_input:  [2]     label_output:  [2]
# n:  858     label_input:  [2]     label_output:  [2]
# n:  859     label_input:  [2]     label_output:  [2]
# n:  860     label_input:  [2]     label_output:  [0]
# n:  861     label_input:  [2]     label_output:  [2]
# n:  862     label_input:  [2]     label_output:  [2]
# n:  863     label_input:  [2]     label_output:  [2]
# n:  864     label_input:  [2]     label_output:  [2]
# n:  865     label_input:  [2]     label_output:  [2]
# n:  866     label_input:  [2]     label_output:  [0]
# n:  867     label_input:  [2]     label_output:  [2]
# n:  868     label_input:  [2]     label_output:  [2]
# n:  869     label_input:  [2]     label_output:  [2]
# n:  870     label_input:  [2]     label_output:  [2]
# n:  871     label_input:  [2]     label_output:  [2]
# n:  872     label_input:  [2]     label_output:  [2]
# n:  873     label_input:  [2]     label_output:  [2]
# n:  874     label_input:  [2]     label_output:  [2]
# n:  875     label_input:  [2]     label_output:  [1]
# n:  876     label_input:  [2]     label_output:  [0]
# n:  877     label_input:  [2]     label_output:  [0]
# n:  878     label_input:  [2]     label_output:  [0]
# n:  879     label_input:  [2]     label_output:  [2]
# n:  880     label_input:  [2]     label_output:  [2]
# n:  881     label_input:  [2]     label_output:  [2]
# n:  882     label_input:  [2]     label_output:  [2]
# n:  883     label_input:  [2]     label_output:  [2]
# n:  884     label_input:  [2]     label_output:  [2]
# n:  885     label_input:  [2]     label_output:  [2]
# n:  886     label_input:  [2]     label_output:  [2]
# n:  887     label_input:  [2]     label_output:  [2]
# n:  888     label_input:  [2]     label_output:  [0]
# n:  889     label_input:  [2]     label_output:  [2]
# n:  890     label_input:  [2]     label_output:  [2]
# n:  891     label_input:  [2]     label_output:  [2]
# n:  892     label_input:  [2]     label_output:  [2]
# n:  893     label_input:  [2]     label_output:  [2]
# n:  894     label_input:  [2]     label_output:  [2]
# n:  895     label_input:  [2]     label_output:  [2]
# n:  896     label_input:  [2]     label_output:  [2]
# n:  897     label_input:  [2]     label_output:  [1]
# n:  898     label_input:  [2]     label_output:  [2]
# n:  899     label_input:  [2]     label_output:  [2]
# n:  900     label_input:  [2]     label_output:  [2]
# n:  901     label_input:  [2]     label_output:  [2]
# n:  902     label_input:  [2]     label_output:  [2]
# n:  903     label_input:  [2]     label_output:  [2]
# n:  904     label_input:  [2]     label_output:  [1]
# n:  905     label_input:  [2]     label_output:  [2]
# n:  906     label_input:  [2]     label_output:  [0]
# n:  907     label_input:  [2]     label_output:  [2]
# n:  908     label_input:  [2]     label_output:  [2]
# n:  909     label_input:  [2]     label_output:  [2]
# n:  910     label_input:  [2]     label_output:  [2]
# n:  911     label_input:  [2]     label_output:  [2]
# n:  912     label_input:  [2]     label_output:  [1]
# n:  913     label_input:  [2]     label_output:  [2]
# n:  914     label_input:  [2]     label_output:  [2]
# n:  915     label_input:  [2]     label_output:  [2]
# n:  916     label_input:  [2]     label_output:  [2]
# n:  917     label_input:  [2]     label_output:  [2]
# n:  918     label_input:  [2]     label_output:  [2]
# n:  919     label_input:  [2]     label_output:  [2]
# n:  920     label_input:  [2]     label_output:  [2]
# n:  921     label_input:  [2]     label_output:  [0]
# n:  922     label_input:  [2]     label_output:  [2]
# n:  923     label_input:  [2]     label_output:  [0]
# n:  924     label_input:  [2]     label_output:  [2]
# n:  925     label_input:  [2]     label_output:  [2]
# n:  926     label_input:  [2]     label_output:  [2]
# n:  927     label_input:  [2]     label_output:  [2]
# n:  928     label_input:  [2]     label_output:  [2]
# n:  929     label_input:  [2]     label_output:  [0]
# n:  930     label_input:  [2]     label_output:  [2]
# n:  931     label_input:  [2]     label_output:  [2]
# n:  932     label_input:  [2]     label_output:  [2]
# n:  933     label_input:  [2]     label_output:  [2]
# n:  934     label_input:  [2]     label_output:  [2]
# n:  935     label_input:  [2]     label_output:  [2]
# n:  936     label_input:  [2]     label_output:  [2]
# n:  937     label_input:  [2]     label_output:  [2]
# n:  938     label_input:  [2]     label_output:  [2]
# n:  939     label_input:  [2]     label_output:  [2]
# n:  940     label_input:  [2]     label_output:  [0]
# n:  941     label_input:  [2]     label_output:  [2]
# n:  942     label_input:  [2]     label_output:  [2]
# n:  943     label_input:  [2]     label_output:  [2]
# n:  944     label_input:  [2]     label_output:  [2]
# n:  945     label_input:  [2]     label_output:  [2]
# n:  946     label_input:  [2]     label_output:  [2]
# n:  947     label_input:  [2]     label_output:  [2]
# n:  948     label_input:  [2]     label_output:  [2]
# n:  949     label_input:  [2]     label_output:  [2]
# n:  950     label_input:  [2]     label_output:  [2]
# n:  951     label_input:  [2]     label_output:  [2]
# n:  952     label_input:  [2]     label_output:  [2]
# n:  953     label_input:  [2]     label_output:  [2]
# n:  954     label_input:  [2]     label_output:  [2]
# n:  955     label_input:  [2]     label_output:  [2]
# n:  956     label_input:  [2]     label_output:  [2]
# n:  957     label_input:  [2]     label_output:  [2]
# n:  958     label_input:  [2]     label_output:  [0]
# n:  959     label_input:  [2]     label_output:  [0]
# n:  960     label_input:  [2]     label_output:  [2]
# n:  961     label_input:  [2]     label_output:  [2]
# n:  962     label_input:  [2]     label_output:  [2]
# n:  963     label_input:  [2]     label_output:  [2]
# n:  964     label_input:  [2]     label_output:  [2]
# n:  965     label_input:  [2]     label_output:  [2]
# n:  966     label_input:  [2]     label_output:  [2]
# n:  967     label_input:  [2]     label_output:  [2]
# n:  968     label_input:  [2]     label_output:  [2]
# n:  969     label_input:  [2]     label_output:  [2]
# n:  970     label_input:  [2]     label_output:  [2]
# n:  971     label_input:  [2]     label_output:  [2]
# n:  972     label_input:  [2]     label_output:  [2]
# n:  973     label_input:  [2]     label_output:  [2]
# n:  974     label_input:  [2]     label_output:  [2]
# n:  975     label_input:  [2]     label_output:  [2]
# n:  976     label_input:  [2]     label_output:  [2]
# n:  977     label_input:  [2]     label_output:  [2]
# n:  978     label_input:  [2]     label_output:  [2]
# n:  979     label_input:  [2]     label_output:  [2]
# n:  980     label_input:  [2]     label_output:  [2]
# n:  981     label_input:  [2]     label_output:  [2]
# n:  982     label_input:  [2]     label_output:  [2]
# n:  983     label_input:  [2]     label_output:  [2]
# n:  984     label_input:  [2]     label_output:  [2]
# n:  985     label_input:  [2]     label_output:  [2]
# n:  986     label_input:  [2]     label_output:  [2]
# n:  987     label_input:  [2]     label_output:  [2]
# n:  988     label_input:  [2]     label_output:  [2]
# n:  989     label_input:  [2]     label_output:  [2]
# n:  990     label_input:  [2]     label_output:  [2]
# n:  991     label_input:  [2]     label_output:  [2]
# n:  992     label_input:  [2]     label_output:  [2]
# n:  993     label_input:  [2]     label_output:  [2]
# n:  994     label_input:  [2]     label_output:  [2]
# n:  995     label_input:  [2]     label_output:  [2]
# n:  996     label_input:  [2]     label_output:  [0]
# n:  997     label_input:  [2]     label_output:  [2]
# n:  998     label_input:  [2]     label_output:  [2]
# n:  999     label_input:  [2]     label_output:  [2]
# n:  1000     label_input:  [2]     label_output:  [2]
# n:  1001     label_input:  [2]     label_output:  [2]
# n:  1002     label_input:  [2]     label_output:  [2]
# n:  1003     label_input:  [2]     label_output:  [2]
# n:  1004     label_input:  [2]     label_output:  [1]
# n:  1005     label_input:  [2]     label_output:  [2]
# n:  1006     label_input:  [2]     label_output:  [2]
# n:  1007     label_input:  [2]     label_output:  [2]
# n:  1008     label_input:  [2]     label_output:  [0]
# n:  1009     label_input:  [2]     label_output:  [2]
# n:  1010     label_input:  [2]     label_output:  [2]
# n:  1011     label_input:  [2]     label_output:  [2]
# n:  1012     label_input:  [2]     label_output:  [2]
# n:  1013     label_input:  [2]     label_output:  [2]
# n:  1014     label_input:  [2]     label_output:  [2]
# n:  1015     label_input:  [2]     label_output:  [2]
# n:  1016     label_input:  [2]     label_output:  [2]
# n:  1017     label_input:  [2]     label_output:  [2]
#
#           TOTAL ACC    :  0.88605
#
# [[0.7388919, 0.1455572, 0.11555089], [0.94662166, 0.01703766, 0.03634075], [0.68125916, 0.050799996, 0.2679409], [0.5670376, 0.40368587, 0.029276548], [0.92920434, 0.045548845, 0.02524676], [0.8429289, 0.041289277, 0.11578189], [0.698692, 0.050999314, 0.25030863], [0.7872094, 0.15990123, 0.052889362], [0.8907732, 0.017956313, 0.091270484], [0.8687537, 0.07572481, 0.055521503], [0.7816142, 0.05902594, 0.15935986], [0.9028107, 0.014781232, 0.08240814], [0.71145755, 0.084392264, 0.20415018], [0.8777801, 0.025605807, 0.096614115], [0.88114446, 0.01419461, 0.10466104], [0.9206741, 0.021879654, 0.05744626], [0.63741845, 0.20430209, 0.1582794], [0.845836, 0.066635825, 0.08752818], [0.7719461, 0.12438397, 0.10366998], [0.6419089, 0.12527002, 0.23282108], [0.8930911, 0.08628833, 0.020620573], [0.73258543, 0.14503361, 0.12238092], [0.87949765, 0.060014088, 0.060488246], [0.87231106, 0.089901276, 0.037787605], [0.95308864, 0.01752112, 0.029390259], [0.9242047, 0.022523217, 0.053272024], [0.7939792, 0.04382727, 0.16219349], [0.9544343, 0.01129554, 0.034270067], [0.896336, 0.015917562, 0.08774646], [0.75809056, 0.073077105, 0.16883224], [0.8524312, 0.025461067, 0.122107856], [0.44293264, 0.13739279, 0.41967458], [0.8646131, 0.02091487, 0.114472], [0.88516194, 0.015648773, 0.09918932], [0.8247627, 0.12126389, 0.053973373], [0.91291374, 0.03691288, 0.050173387], [0.90985703, 0.05238179, 0.037761226], [0.8788438, 0.040245764, 0.08091038], [0.76375145, 0.15167204, 0.08457655], [0.9468391, 0.019044977, 0.034115955], [0.6366291, 0.17492627, 0.18844467], [0.92920655, 0.041602246, 0.029191276], [0.64863235, 0.080499575, 0.270868], [0.7730245, 0.1983715, 0.028604088], [0.7237019, 0.08908653, 0.18721162], [0.6342337, 0.29857293, 0.06719334], [0.91369337, 0.03238751, 0.053919155], [0.91976357, 0.019962182, 0.060274225], [0.87585396, 0.07363386, 0.0505122], [0.24236359, 0.5681102, 0.18952617], [0.8983144, 0.015208114, 0.08647753], [0.69289064, 0.06648186, 0.2406275], [0.8574175, 0.0501384, 0.09244401], [0.8073005, 0.13250335, 0.060196098], [0.9058263, 0.032977685, 0.061196078], [0.62121934, 0.11953233, 0.2592483], [0.90727395, 0.008596666, 0.084129415], [0.9252049, 0.014370004, 0.060425155], [0.9570529, 0.008285391, 0.034661632], [0.90345657, 0.024288507, 0.07225495], [0.9063222, 0.047479168, 0.04619867], [0.7861012, 0.11074758, 0.103151195], [0.8427313, 0.079223536, 0.07804513], [0.9683235, 0.008815853, 0.022860609], [0.9508417, 0.011686219, 0.03747209], [0.82288444, 0.040803403, 0.1363122], [0.34645092, 0.48449385, 0.16905518], [0.7955301, 0.11649753, 0.08797231], [0.8312667, 0.083818235, 0.084915064], [0.9271192, 0.04181601, 0.031064743], [0.872588, 0.099477485, 0.027934486], [0.9438037, 0.010816723, 0.045379523], [0.44901094, 0.3325594, 0.2184297], [0.9004257, 0.010952693, 0.088621646], [0.9105727, 0.043346345, 0.046080973], [0.9214004, 0.058680017, 0.01991959], [0.9218988, 0.03929082, 0.038810372], [0.955326, 0.015584698, 0.029089374], [0.845811, 0.027576877, 0.1266121], [0.9451966, 0.0052581127, 0.04954524], [0.95413065, 0.012126663, 0.033742666], [0.8194631, 0.026630247, 0.15390669], [0.67245084, 0.28974667, 0.037802517], [0.8971223, 0.007891936, 0.09498574], [0.9556292, 0.020208728, 0.024162078], [0.8484762, 0.051121183, 0.10040263], [0.44746917, 0.43942335, 0.11310752], [0.69974554, 0.16052574, 0.13972875], [0.8722514, 0.059518106, 0.06823057], [0.9619588, 0.01982906, 0.018212168], [0.94031644, 0.034123145, 0.025560472], [0.92231995, 0.015209161, 0.062470872], [0.9552933, 0.01568145, 0.029025197], [0.30520013, 0.45685026, 0.23794952], [0.87470925, 0.03095122, 0.09433959], [0.7630639, 0.08222324, 0.15471284], [0.92786187, 0.03215474, 0.039983433], [0.9627851, 0.014857998, 0.022356894], [0.72444636, 0.110826895, 0.16472676], [0.93590987, 0.021808496, 0.042281568], [0.8570239, 0.07570409, 0.06727199], [0.60837114, 0.23316155, 0.15846732], [0.8439984, 0.06601938, 0.0899822], [0.5946897, 0.3370036, 0.06830663], [0.8713108, 0.0127773285, 0.11591187 ...
#
# =======================================================================================
# 002:45:24
# =======================================================================================
